# %% [markdown]
# Sampling the Muller potential

# %%
# %pylab inline
import numpy as np
from msmbuilder.example_datasets import MullerPotential
from msmbuilder.example_datasets._muller import propagate
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mp = MullerPotential()

# %%
#lets start by plotting the potential surface
mp.plot()

# %%
res=propagate(n_steps=500,x0=(.5,0))

# %%
mp.plot()
scatter(res[:,0],res[:,1])
